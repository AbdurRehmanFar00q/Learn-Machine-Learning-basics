# %% [markdown]
# ## What is Scikit-learn?
#
# 👉 A Python library to:
#
# Train ML models  <br>
# Evaluate models <br>
# Preprocess data <br>

# %% [markdown]
# ## 🎯 What You Must Learn (Important Areas)

# %% [markdown]
# ### Basic Workflow (MOST IMPORTANT)

# %% [markdown]
# 1. Load data
# 2. Split data
# 3. Train model
# 4. Predict
# 5. Evaluate

# %% [markdown]
# ## Models You Must Know

# %% [markdown]
# ### 📈 A. Regression (Predict numbers)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 👉 Example:
#
# House price prediction
#
#
# Salary prediction

# %% [markdown]
# ### 📊 B. Classification (Predict category)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# 👉 Example:
#
# Spam detection
#
#
# Pass/Fail

# %% [markdown]
# ### 📊 C. Clustering (Unsupervised)

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# 👉 Example:
#
# Customer segmentation

# %% [markdown]
# # Train-Test Split
#
# 👉 Prevents overfitting

# %%
train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Model Evaluation (VERY IMPORTANT)

# %% [markdown]
# ## 👉 Check how good model is

# %% [markdown]
# ### Regression Metrics

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, pred)

# %% [markdown]
# ### Classification Metrics

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, pred)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## 👉 ML models need clean data

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ### Encoding (text → number)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

# %% [markdown]
# # Pipeline (Advanced but Important)

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# 👉 Combines preprocessing + model

# %% [markdown]
# # Save Model

# %%
import joblib

joblib.dump(model, "model.pkl")

# %% [markdown]
# #  Complete ML Workflow Explained

# %% [markdown]
# ##  Steps:
# Load Data
#
#
# Split Data
#
#
# Train Model
#
#
# Predict
#
#
# Evaluate
#
# #### Now solve these steps one by one
